# %% [markdown]
# # Pretrained Model (ResNet34, CIFAR10)

# %%
''' 1. Module Import '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.10.2  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. Data Augmentation이 적용된 CIFAR10 데이터 다운로드 (Train set, Test set 분리하기) '''
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

train_dataset = datasets.CIFAR10(root = "/data_aug/CIFAR_10",
                                  train = True,
                                  download = True,
                                  transform = transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))

test_dataset = datasets.CIFAR10(root = "/data_aug/CIFAR_10",
                                train = False,
                                transform = transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                            batch_size = BATCH_SIZE,
                                            shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Files already downloaded and verified

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 5. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Not pre-trained model (from scratch 학습?)

# %%
''' 6. PyTorch 내에서 제공하는 ResNet34 모델 불러온 후 FC 층 추가 및 Output 크기 설정하기 '''
import torchvision.models as models
model = models.resnet34(pretrained = False)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)
model = model.cuda()

# %%
''' 7. Optimizer, Objective Function 설정하기 '''
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
''' 8. 불러온 Resnet34 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), 
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
''' 9. 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의 '''
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
if torch.cuda.is_available():
    train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                               num_workers=12,
                                                batch_size = BATCH_SIZE,
                                                shuffle = True,
                                              persistent_workers=True)

# %%
# %%time

''' 10. 불러온 ResNet34 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인하기 '''

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.919812
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 1.743259
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.566871
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 1.388460
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.574700
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 1.251327
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 1.061568
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.620300
#
# [EPOCH: 1], 	Test Loss: 1.1899, 	Test Accuracy: 58.96 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 0.860132
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.303953
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.249170
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.122847
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.400946
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.455236
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 0.851767
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.082469
#
# [EPOCH: 2], 	Test Loss: 1.0760, 	Test Accuracy: 62.54 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 0.697131
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 0.951927
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 0.734637
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 0.812440
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 0.834280
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 0.896067
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.055412
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 0.837801
#
# [EPOCH: 3], 	Test Loss: 0.9714, 	Test Accuracy: 66.78 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 0.979610
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 0.694328
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 0.868795
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 1.132281
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 0.890664
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 0.460325
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 0.841902
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 0.928272
#
# [EPOCH: 4], 	Test Loss: 0.8292, 	Test Accuracy: 71.10 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 0.730203
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 0.551458
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 0.547705
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 0.647736
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 0.899663
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 0.621998
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 0.307174
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 0.490677
#
# [EPOCH: 5], 	Test Loss: 0.7864, 	Test Accuracy: 73.80 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 0.875795
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 0.685861
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 1.423556
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 0.684154
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 0.935241
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 0.681770
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 0.738122
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 0.646437
#
# [EPOCH: 6], 	Test Loss: 0.6948, 	Test Accuracy: 76.29 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 0.424891
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 0.529601
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 0.717810
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 0.487448
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 0.667814
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 0.663525
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 0.646830
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 0.472723
#
# [EPOCH: 7], 	Test Loss: 0.6847, 	Test Accuracy: 76.80 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 0.467242
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 0.615325
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 0.261336
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 0.539270
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 0.634401
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 0.681772
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 0.470420
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 0.248577
#
# [EPOCH: 8], 	Test Loss: 0.6698, 	Test Accuracy: 77.08 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 0.573427
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 0.430164
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 0.625942
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 0.633825
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 0.560784
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 0.505312
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 0.526383
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 0.297591
#
# [EPOCH: 9], 	Test Loss: 0.6717, 	Test Accuracy: 76.98 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 0.374140
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 0.563074
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 0.340294
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 0.452479
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 0.370129
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 0.472033
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 0.563931
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 0.280834
#
# [EPOCH: 10], 	Test Loss: 0.6413, 	Test Accuracy: 78.97 %
#
# CPU times: total: 8min 53s
# Wall time: 8min 54s

# %% [markdown]
# ## pre-trained model (FC층만 학습?)

# %%
# %%time

''' 11. IMAGENET 데이터로 학습이 된 ResNet34 모델을 불러온 후 Fine Tuning 해보기 '''
model = models.resnet34(pretrained = True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to C:\Users\user/.cache\torch\hub\checkpoints\resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.754993
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 1.236744
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.290043
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 0.885365
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.029635
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 0.951153
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 0.861316
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.133375
#
# [EPOCH: 1], 	Test Loss: 0.9245, 	Test Accuracy: 67.59 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 0.922668
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 0.555641
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 0.678834
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 0.959351
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 0.779120
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 0.755628
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 0.694353
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 0.972591
#
# [EPOCH: 2], 	Test Loss: 1.1278, 	Test Accuracy: 72.14 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 0.840867
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 0.746259
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 0.523342
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 0.759399
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 0.843191
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 0.617259
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 0.435842
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 0.410329
#
# [EPOCH: 3], 	Test Loss: 0.6626, 	Test Accuracy: 77.60 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 0.632780
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 0.678427
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 0.498009
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 0.424267
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 0.441904
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 0.902282
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 0.783078
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 0.677568
#
# [EPOCH: 4], 	Test Loss: 0.6469, 	Test Accuracy: 78.91 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 0.817869
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 0.520316
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 0.332289
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 0.563503
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 0.164265
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 0.558647
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 0.753412
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 0.411131
#
# [EPOCH: 5], 	Test Loss: 0.9281, 	Test Accuracy: 72.11 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 0.595657
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 0.201944
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 0.628467
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 0.326430
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 0.650999
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 0.590687
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 0.774263
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 0.266653
#
# [EPOCH: 6], 	Test Loss: 0.6703, 	Test Accuracy: 79.16 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 0.469807
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 0.490011
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 0.333429
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 0.280651
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 0.382036
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 0.660437
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 0.691471
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 0.553459
#
# [EPOCH: 7], 	Test Loss: 0.6285, 	Test Accuracy: 78.60 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 0.429193
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 0.519478
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 0.216746
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 0.605776
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 0.505386
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 0.492441
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 0.319595
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 0.150766
#
# [EPOCH: 8], 	Test Loss: 0.8308, 	Test Accuracy: 75.48 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 0.933315
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 0.629592
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 0.339479
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 0.366976
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 0.469849
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 0.540991
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 0.248121
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 0.226578
#
# [EPOCH: 9], 	Test Loss: 0.7039, 	Test Accuracy: 79.81 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 0.670956
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 0.271105
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 0.275262
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 0.459293
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 0.324454
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 0.221598
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 0.270928
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 0.400886
#
# [EPOCH: 10], 	Test Loss: 0.5861, 	Test Accuracy: 81.21 %
#
# CPU times: total: 8min 40s
# Wall time: 8min 34s
